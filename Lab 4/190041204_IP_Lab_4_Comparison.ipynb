# %%
import numpy as np
import matplotlib.pyplot as plt


# creating the dataset
data = {'Static':1, 'Simple Global':978.5, 'Dynamic Global':17,  'Mixed Global':6, 'RIP':1 , 'RIPng':1}
Routing_Protocol = list(data.keys())
Packets = list(data.values())

fig = plt.figure(figsize = (10, 5))

# creating the bar plot
plt.bar(Routing_Protocol, Packets, color ='blue',
		width = 0.4)

plt.xlabel("Routing Protocols")
plt.ylabel("Average Packets")
plt.title("Routing Protocols vs Avg Packets")
plt.show()

# %%
# creating the dataset
data = {'Static':0.006562, 'Simple Global':0.0157579, 'Dynamic Global':0.008570725,  'Mixed Global':0.0167427, 'RIP':0.0094868 , 'RIPng':0.002433}
Routing_Protocol = list(data.keys())
End = list(data.values())

fig = plt.figure(figsize = (10, 5))

# creating the bar plot
plt.bar(Routing_Protocol, End, color ='orange',
		width = 0.4)

plt.xlabel("Routing Protocols")
plt.ylabel("Average End to End Delay(s)")
plt.title("Routing Protocols vs End to End Delay")
plt.show()

# %%
# creating the dataset
data = {'Static':185.309, 'Simple Global':472.151, 'Dynamic Global':2.3055725,  'Mixed Global':0.560364, 'RIP':146.561975 , 'RIPng':828.607}
Routing_Protocol = list(data.keys())
through = list(data.values())

fig = plt.figure(figsize = (10, 5))

# creating the bar plot
plt.bar(Routing_Protocol, through, color ='maroon',
		width = 0.4)

plt.xlabel("Routing Protocols")
plt.ylabel("Average Throughput(Kbps)")
plt.title("Routing Protocols vs Average Throughput")
plt.show()
